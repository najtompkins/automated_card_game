# %%
import pydealer as pd # For card/stack/deck classes
from time import sleep # For optional delay between rounds
from IPython.display import clear_output # To Clear Jupyter cell outputs

# %% [markdown]
# # Testing Code

# %%
# build the starting deck
starting_deck = pd.Deck()
# shuffle the deck
# starting_deck.shuffle()

# deal the cards to player variables
player_1_cards = starting_deck.deal(26)
player_2_cards = starting_deck.deal(26)

# build player 1's starting hand
player_1_hand = pd.Stack()
player_1_hand.add(player_1_cards)
# build player 2's starting hand
player_2_hand = pd.Stack()
player_2_hand.add(player_2_cards)


# build player 1's discard pile
player_1_discard = pd.Stack()
# build player 2's discard pile
player_2_discard = pd.Stack()

# build player 1's war stack
player_1_war = pd.Stack()
# build player 2's war stack
player_2_war = pd.Stack()

# %%
for card in player_1_hand:
    print(card.value, card.suit)
# Out:
# Ace Spades
# Ace Hearts
# Ace Clubs
# Ace Diamonds
# King Spades
# King Hearts
# King Clubs
# King Diamonds
# Queen Spades
# Queen Hearts
# Queen Clubs
# Queen Diamonds
# Jack Spades
# Jack Hearts
# Jack Clubs
# Jack Diamonds
# 10 Spades
# 10 Hearts
# 10 Clubs
# 10 Diamonds
# 9 Spades
# 9 Hearts
# 9 Clubs
# 9 Diamonds
# 8 Spades
# 8 Hearts

# %%
# Print the first card in each player's hand

print(f"Player 1's first card: {player_1_hand[0].value} of {player_1_hand[0].suit}")
print(f"Player 2's first card: {player_2_hand[0].value} of {player_2_hand[0].suit}")
player_1_hand[0].eq(player_2_hand[0], POKER_RANKS)
# Out:
# Player 1's first card: Ace of Spades
# Player 2's first card: 8 of Clubs
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[118], line 5
#       3 print(f"Player 1's first card: {player_1_hand[0].value} of {player_1_hand[0].suit}")
#       4 print(f"Player 2's first card: {player_2_hand[0].value} of {player_2_hand[0].suit}")
# ----> 5 player_1_hand[0].eq(player_2_hand[0], POKER_RANKS)
#
# NameError: name 'POKER_RANKS' is not defined

# %%
player_1_hand.name = "Player 1's Hand"
player_1_discard.name = "Player 1's Discard Pile"
player_1_war.name = "Player 1's War Stack"

player_2_hand.name = "Player 2's Hand"
player_2_discard.name = "Player 2's Discard Pile"
player_2_war.name = "Player 2's War Stack"

# %%
# RUN AFTER CELL BELOW!
# Testing the try/except statements using custom error function
try:
    if len(player_1_hand) == 0:
        raise NoCards("Player 1's hand is empty") 
    elif len(player_1_hand) > 0:
        player_1_war.add(player_1_hand.deal(1))   
except NoCards as e:
    print(e)
    temporary = 1
# Out:
# Player 1's hand is empty

# %% [markdown]
# # War Simulation Functions and Custom Error declarations

# %% [markdown]
# ## Custom Error function

# %%
# Raises error when player's hand is empty

class NoCards(Exception):
    def __init__(self, message):
        self.message = message
        super().__init__(self.message)

# %%
# Deals card(s) to specified player's war_stack from the top (index -1) of the player's hand
# Returns error code 10 if player's hand is empty. None if deal was successful.

def deal(player_hand, player_war_stack, number_of_cards):
    # Deal the top cards from the player's hand and place them into the war stack
    print(f"--Dealing Cards to {player_hand.name}--")
    print(f"Before dealing, The Player's war_stack size: {len(player_war_stack)}")

    try:
        if len(player_hand) == 0:
            raise NoCards("Player's hand is empty")
        elif len(player_hand) > 0:
            temp_card = player_hand.deal(number_of_cards)
            player_war_stack.add(temp_card)
            print(f"--[{temp_card}]-- Card Dealt Successfully to {player_hand.name}--")
    except NoCards as e:
        print(e)
        return 10
    print(f"After dealing, the Player's war_stack  size: {len(player_war_stack)}")

# %%
# Compares the top cards in the player's war_stacks.
# Returns error code 10 if player's hand is empty
    # Returns code 0 if there is a war
    # Returns code 1 if player 1 wins
    # Returns code 2 if player 2 wins

def compare():
    print(f"--Comparing the player cards. ({len(player_1_war)} in 1's war stack, {len(player_2_war)} in 2's war stack)--")
    # assign the top cards in the war stack to variables.
    top_card_1 = player_1_war[-1]
    top_card_2 = player_2_war[-1]

    print(f"Player 1's card --> {top_card_1} / {top_card_2} <-- Player 2's card")
    # Compare the cards
    if top_card_1.value > top_card_2.value: # if player 1's card is greater than player 2's
        print(f"Player 1 wins the round with the {top_card_1}!")
        return 1
    elif top_card_1.value < top_card_2.value: # if player 1's card is less than player 2's
        print(f"Player 2 wins the round with the {top_card_2}!")
        return 2
    elif top_card_1.value == top_card_2.value: # if player 1's card is equal to player 2's
        print(f"Neither player wins! It's a war!")
        return 0
    else: # if something went wrong
        print("Something went wrong!")
        return 10

# %%
# Moves all cards from the both player's war stack into the their respective discard hands
# Based on result value (0, 1, or 2) which is passed into function after comparison function returns a verdict.

def reset_war_stacks(result):
    print(f"--Resetting the war stacks from 1's {len(player_1_war)} and 2's {len(player_2_war)} to Zero (0)--")
    # reset the war stacks

    if result == 1:
        print(f"Player 1 won the round, so all cards go to {player_1_discard.name}")

        # reset player 1's war stack into player_1_discard
        for i in range(len(player_1_war)):
            temp_card = player_1_war.deal(1)
            player_1_discard.add(temp_card)

        # reset player 2's war stack into player_1_discard
        for i in range(len(player_2_war)):
            temp_card = player_2_war.deal(1)
            player_1_discard.add(temp_card)
    
    elif result == 2:

        print(f"Player 2 won the round, so all cards go to {player_2_discard.name}")
        # reset player 1's war stack into player_2_discard
        for i in range(len(player_1_war)):
            temp_card = player_1_war.deal(1)
            player_2_discard.add(temp_card)

        # reset player 2's war stack into player_2_discard
        for i in range(len(player_2_war)):
            temp_card = player_2_war.deal(1)
            player_2_discard.add(temp_card)

    # Further else statements only show when something went wrong. They should never print in a functioning game.
    elif result == 10:
        print("Cannot reset stacks when comparison errors (value 10) are passed into reset function")
    
    elif result == 0:
        print("Hey there's a war going on! Cannot reset the stacks right now!")

    else: print("Something went wrong when resetting the stacks.")

# %%
# Empties discard pile of specified player into hand of specified player.
    # Returns error code 10 if player's discard pile is empty
    # Returns None if discard pile is successfully emptied into the player's hand

def empty_discard_pile(player_hand, player_discard_pile):
    print(f"--Attempting to empty the discard pile for {player_1_discard.name}--")

    # Check if the discard pile is empty, returning error code 10 if so
    if len(player_discard_pile) == 0:
        print(f"{player_hand.name} is empty, returning error code 10")
        return 10
    
    # Empty discard pile into player hand
    elif len(player_discard_pile) > 0:
        print(f"{player_discard_pile.name} is not empty: There are {len(player_discard_pile)} cards in it. Emptying into {player_hand.name}")
        for card in player_discard_pile:
            temp_card = player_discard_pile.deal(1)
            player_hand.add(temp_card)

    # shuffle the player hand
    print(f"Shuffling {player_hand.name}")
    player_hand.shuffle()

# %%
# Performs final check for winner (all player stacks are empty), returning Boolean value.

def check_for_winner(player_hand, player_war_stack, player_discard):
    if ((len(player_hand)) + (len(player_war_stack)) + (len(player_discard))) == 0:
        return True
    else:
        return False

# %% [markdown]
# ## War Simulator Prototype

# %%
# Prototype war round. Run Cell each game.

# build the starting deck
starting_deck = pd.Deck()
# shuffle the deck
starting_deck.shuffle()

# deal the cards to player variables
player_1_cards = starting_deck.deal(26)
player_2_cards = starting_deck.deal(26)

# build player 1's starting hand
player_1_hand = pd.Stack()
player_1_hand.add(player_1_cards)
# build player 2's starting hand
player_2_hand = pd.Stack()
player_2_hand.add(player_2_cards)

# build player 1's discard pile
player_1_discard = pd.Stack()
# build player 2's discard pile
player_2_discard = pd.Stack()

# build player 1's war stack
player_1_war = pd.Stack()
# build player 2's war stack
player_2_war = pd.Stack()

# Naming the Stacks for better output readability of print statements
player_1_hand.name = "Player 1's Hand"
player_1_discard.name = "Player 1's Discard Pile"
player_1_war.name = "Player 1's War Stack"

player_2_hand.name = "Player 2's Hand"
player_2_discard.name = "Player 2's Discard Pile"
player_2_war.name = "Player 2's War Stack"

# Simulate War
round = 0
condition = True
while condition:
    # label the round
    print("*********************************")
    round += 1
    print(f"Round {round}")
    # print("\/\/\/\/\/\/\/\/\/\/\/\/\/")
    
    # deal the cards
    deal_1_result = deal(player_1_hand, player_1_war, 1)
    # print(f'The result for Deal 1 is: ({deal_1_result}) ')
    deal_2_result = deal(player_2_hand, player_2_war, 1)
    # print(f'The result for Deal 2 is: ({deal_2_result}) ')
    
    # test the error result, if it is None (no error) then compare the cards
    
    # Check if both hands are empty
    if deal_1_result == 10 and deal_2_result == 10:

        discard_result_1 = empty_discard_pile(player_1_hand, player_1_discard)
        discard_result_2 = empty_discard_pile(player_2_hand, player_2_discard)
        if discard_result_1 == 10:
            print("Player 2 Wins")
            break
        elif discard_result_2 == 10:
            print("Player 1 Wins")
            break

    # Check if Player 1 is out of cards but not Player 2
    elif deal_1_result == 10 and deal_2_result == None:
        discard_result = empty_discard_pile(player_1_hand, player_1_discard)
        if discard_result == 10:
            print("Player 2 Wins")
            break
        elif discard_result == None:
            deal_1_result = deal(player_1_hand, player_1_war, 1)

    # Check if Player 2 is out of cards but not Player 1
    elif deal_2_result == 10 and deal_1_result == None:
        discard_result = empty_discard_pile(player_2_hand, player_2_discard)
        if discard_result == 10:
            print("Player 1 Wins")
            break
        elif discard_result == None:
            deal_2_result = deal(player_2_hand, player_2_war, 1)

    # Compare the cards
    elif deal_1_result == None and deal_2_result == None:
        result = compare()
        if result == 0:
            print("There was a war!")
            # While comparison is in war mode (0)
            while result == 0:
                # Deal 4 times, (0-3) Top card (is the fourth card dealt)
                for i in range(4):
                    deal_1_result = deal(player_1_hand, player_1_war, 1)
                    deal_2_result = deal(player_2_hand, player_2_war, 1)

                    # If they're both out of cards, use their discard piles
                    if deal_1_result == 10 and deal_2_result == 10:
                        discard_result_1 = empty_discard_pile(player_1_hand, player_1_discard)
                        discard_result_2 = empty_discard_pile(player_2_hand, player_2_discard)
                        if discard_result_1 == 10:
                            result = 2
                            break
                        elif discard_result_1 == None:
                            deal_1_result = deal(player_1_hand, player_1_war, 1)
                        
                        if discard_result_2 == 10:
                            result = 1
                            break
                        elif discard_result_2 == None:
                            deal_2_result = deal(player_2_hand, player_2_war, 1)

                    # If Player 1 is out of cards but not Player 2, set result = 2 (player 2 wins), re-deal for player 1
                    elif deal_1_result == 10 and deal_2_result == None:
                        discard_result_1 = empty_discard_pile(player_1_hand, player_1_discard)
                        if discard_result_1 == 10:
                            result = 2
                            break
                        elif discard_result_1 == None:
                            deal_1_result = deal(player_1_hand, player_1_war, 1)

                    # If Player 2 is out of cards but not Player 1, set result = 1 (player 1 wins) and re-deal for player 2
                    elif deal_2_result == 10 and deal_1_result == None:
                        discard_result_2 = empty_discard_pile(player_2_hand, player_2_discard)
                        if discard_result_2 == 10:    
                            result = 1
                            break
                        elif discard_result_2 == None:
                            deal_2_result = deal(player_2_hand, player_2_war, 1)
                    
                # Once neither player is out of cards, compare the cards
                if deal_1_result == None and deal_2_result == None:
                    war_result = compare()
                    # If player 1 wins, then set result to 1 and break the deal loop
                    if war_result == 1:
                        result = 1
                        print(f"Player 1 Wins The War at round {round}!")
                        break
                    # If player 2 wins, then set result to 2 and break the deal loop
                    elif war_result == 2:
                        result = 2
                        print(f"Player 2 Wins The War at round {round}!")
                        break
                    # If there was another war, then keep/set result at 0 and continue
                    elif war_result == 0:
                        result = 0
                        print(f"There was another war at round {round}!")
                        continue
                    # If there was in error when comparing, this should print
                    elif war_result == 10:
                        print(f"There was an error when performing a war_check comparison at round {round}.")
                        break

                       
    reset_war_stacks(result)
    print("****Player Totals****")
    print(f"The total length of {player_1_hand.name} and {player_1_discard.name} is:, {len(player_1_hand)} + {len(player_1_discard)}, or {len(player_1_hand) + len(player_1_discard)}, at the end of round {round}")
    print(f"The total length of {player_2_hand.name} and {player_2_discard.name} is:, {len(player_2_hand)} + {len(player_2_discard)}, or {len(player_2_hand) + len(player_2_discard)}, at the end of round {round}")


    # Check for a winner and store boolean values in variables
    did_player_1_win = check_for_winner(player_1_hand, player_1_war, player_1_discard)
    did_player_2_win = check_for_winner(player_2_hand, player_2_war, player_2_discard)

    # If either player won, break the loop and print the winner
    if did_player_1_win == True:
        print("Player 1 Wins the game!")
        break
    elif did_player_2_win == True:
        print("Player 2 Wins the game!")
        break


    # Clear jupter output every 100 iterations
    # This has the unintended consequence of showing no output if the last round simulated is a multiple of 100
    if round % 100 == 0:
        clear_output(wait=True)
# Out:
# *********************************
# Round 1
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[7 of Hearts]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[4 of Hearts]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 7 of Hearts / 4 of Hearts <-- Player 2's card
# Player 1 wins the round with the 7 of Hearts!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 25 + 2, or 27, at the end of round 1
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 25 + 0, or 25, at the end of round 1
# *********************************
# Round 2
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Ace of Diamonds]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Queen of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> Ace of Diamonds / Queen of Diamonds <-- Player 2's card
# Player 2 wins the round with the Queen of Diamonds!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 24 + 2, or 26, at the end of round 2
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 24 + 2, or 26, at the end of round 2
# *********************************
# Round 3
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[7 of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[2 of Hearts]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 7 of Spades / 2 of Hearts <-- Player 2's card
# Player 1 wins the round with the 7 of Spades!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 23 + 4, or 27, at the end of round 3
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 23 + 2, or 25, at the end of round 3
# *********************************
# Round 4
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Jack of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[2 of Clubs]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> Jack of Spades / 2 of Clubs <-- Player 2's card
# Player 1 wins the round with the Jack of Spades!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 22 + 6, or 28, at the end of round 4
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 22 + 2, or 24, at the end of round 4
# *********************************
# Round 5
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[9 of Clubs]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[6 of Clubs]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 9 of Clubs / 6 of Clubs <-- Player 2's card
# Player 1 wins the round with the 9 of Clubs!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 21 + 8, or 29, at the end of round 5
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 21 + 2, or 23, at the end of round 5
# *********************************
# Round 6
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[8 of Hearts]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[10 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 8 of Hearts / 10 of Diamonds <-- Player 2's card
# Player 1 wins the round with the 8 of Hearts!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 20 + 10, or 30, at the end of round 6
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 20 + 2, or 22, at the end of round 6
# *********************************
# Round 7
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[King of Clubs]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[4 of Spades]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> King of Clubs / 4 of Spades <-- Player 2's card
# Player 1 wins the round with the King of Clubs!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 19 + 12, or 31, at the end of round 7
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 19 + 2, or 21, at the end of round 7
# *********************************
# Round 8
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[5 of Hearts]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[10 of Clubs]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 5 of Hearts / 10 of Clubs <-- Player 2's card
# Player 1 wins the round with the 5 of Hearts!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 18 + 14, or 32, at the end of round 8
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 18 + 2, or 20, at the end of round 8
# *********************************
# Round 9
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[2 of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[King of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 2 of Spades / King of Diamonds <-- Player 2's card
# Player 2 wins the round with the King of Diamonds!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 17 + 14, or 31, at the end of round 9
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 17 + 4, or 21, at the end of round 9
# *********************************
# Round 10
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[3 of Diamonds]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[8 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 3 of Diamonds / 8 of Diamonds <-- Player 2's card
# Player 2 wins the round with the 8 of Diamonds!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 16 + 14, or 30, at the end of round 10
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 16 + 6, or 22, at the end of round 10
# *********************************
# Round 11
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[9 of Hearts]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[9 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 9 of Hearts / 9 of Diamonds <-- Player 2's card
# Neither player wins! It's a war!
# There was a war!
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 1
# --[6 of Hearts]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 2
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 1
# --[4 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 2
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 2
# --[10 of Hearts]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 3
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 2
# --[5 of Clubs]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 3
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 3
# --[3 of Hearts]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 4
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 3
# --[7 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 4
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 4
# --[Ace of Hearts]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 5
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 4
# --[Jack of Clubs]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 5
# --Comparing the player cards. (5 in 1's war stack, 5 in 2's war stack)--
# Player 1's card --> Ace of Hearts / Jack of Clubs <-- Player 2's card
# Player 2 wins the round with the Jack of Clubs!
# Player 2 Wins The War at round 11!
# --Resetting the war stacks from 1's 5 and 2's 5 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 11 + 14, or 25, at the end of round 11
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 11 + 16, or 27, at the end of round 11
# *********************************
# Round 12
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[7 of Clubs]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[3 of Clubs]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 7 of Clubs / 3 of Clubs <-- Player 2's card
# Player 1 wins the round with the 7 of Clubs!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 10 + 16, or 26, at the end of round 12
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 10 + 16, or 26, at the end of round 12
# *********************************
# Round 13
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Queen of Clubs]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[6 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> Queen of Clubs / 6 of Diamonds <-- Player 2's card
# Player 1 wins the round with the Queen of Clubs!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 9 + 18, or 27, at the end of round 13
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 9 + 16, or 25, at the end of round 13
# *********************************
# Round 14
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[3 of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[8 of Clubs]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 3 of Spades / 8 of Clubs <-- Player 2's card
# Player 2 wins the round with the 8 of Clubs!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 8 + 18, or 26, at the end of round 14
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 8 + 18, or 26, at the end of round 14
# *********************************
# Round 15
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Queen of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[8 of Spades]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> Queen of Spades / 8 of Spades <-- Player 2's card
# Player 1 wins the round with the Queen of Spades!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 7 + 20, or 27, at the end of round 15
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 7 + 18, or 25, at the end of round 15
# *********************************
# Round 16
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Ace of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Jack of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> Ace of Spades / Jack of Diamonds <-- Player 2's card
# Player 2 wins the round with the Jack of Diamonds!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 6 + 20, or 26, at the end of round 16
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 6 + 20, or 26, at the end of round 16
# *********************************
# Round 17
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[10 of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[6 of Spades]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 10 of Spades / 6 of Spades <-- Player 2's card
# Player 2 wins the round with the 6 of Spades!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 5 + 20, or 25, at the end of round 17
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 5 + 22, or 27, at the end of round 17
# *********************************
# Round 18
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Queen of Hearts]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[5 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> Queen of Hearts / 5 of Diamonds <-- Player 2's card
# Player 1 wins the round with the Queen of Hearts!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 4 + 22, or 26, at the end of round 18
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 4 + 22, or 26, at the end of round 18
# *********************************
# Round 19
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[King of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[9 of Spades]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> King of Spades / 9 of Spades <-- Player 2's card
# Player 1 wins the round with the King of Spades!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 3 + 24, or 27, at the end of round 19
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 3 + 22, or 25, at the end of round 19
# *********************************
# Round 20
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[4 of Clubs]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[King of Hearts]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 4 of Clubs / King of Hearts <-- Player 2's card
# Player 2 wins the round with the King of Hearts!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 2 + 24, or 26, at the end of round 20
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 2 + 24, or 26, at the end of round 20
# *********************************
# Round 21
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[5 of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Ace of Clubs]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 5 of Spades / Ace of Clubs <-- Player 2's card
# Player 2 wins the round with the Ace of Clubs!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 1 + 24, or 25, at the end of round 21
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 1 + 26, or 27, at the end of round 21
# *********************************
# Round 22
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Jack of Hearts]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[2 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> Jack of Hearts / 2 of Diamonds <-- Player 2's card
# Player 1 wins the round with the Jack of Hearts!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 0 + 26, or 26, at the end of round 22
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 0 + 26, or 26, at the end of round 22
# *********************************
# Round 23
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# Player's hand is empty
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# Player's hand is empty
# --Attempting to empty the discard pile for Player 1's Discard Pile--
# Player 1's Discard Pile is not empty: There are 26 cards in it. Emptying into Player 1's Hand
# Shuffling Player 1's Hand
# --Attempting to empty the discard pile for Player 1's Discard Pile--
# Player 2's Discard Pile is not empty: There are 26 cards in it. Emptying into Player 2's Hand
# Shuffling Player 2's Hand
# --Resetting the war stacks from 1's 0 and 2's 0 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 13 + 13, or 26, at the end of round 23
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 13 + 13, or 26, at the end of round 23
# *********************************
# Round 24
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Queen of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[10 of Spades]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> Queen of Spades / 10 of Spades <-- Player 2's card
# Player 1 wins the round with the Queen of Spades!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 12 + 15, or 27, at the end of round 24
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 12 + 13, or 25, at the end of round 24
# *********************************
# Round 25
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[7 of Clubs]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[4 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 7 of Clubs / 4 of Diamonds <-- Player 2's card
# Player 1 wins the round with the 7 of Clubs!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 11 + 17, or 28, at the end of round 25
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 11 + 13, or 24, at the end of round 25
# *********************************
# Round 26
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[King of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[4 of Clubs]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> King of Spades / 4 of Clubs <-- Player 2's card
# Player 1 wins the round with the King of Spades!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 10 + 19, or 29, at the end of round 26
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 10 + 13, or 23, at the end of round 26
# *********************************
# Round 27
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[9 of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Ace of Spades]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 9 of Spades / Ace of Spades <-- Player 2's card
# Player 2 wins the round with the Ace of Spades!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 9 + 19, or 28, at the end of round 27
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 9 + 15, or 24, at the end of round 27
# *********************************
# Round 28
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[5 of Diamonds]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[3 of Spades]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 5 of Diamonds / 3 of Spades <-- Player 2's card
# Player 1 wins the round with the 5 of Diamonds!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 8 + 21, or 29, at the end of round 28
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 8 + 15, or 23, at the end of round 28
# *********************************
# Round 29
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[3 of Clubs]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[King of Hearts]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 3 of Clubs / King of Hearts <-- Player 2's card
# Player 2 wins the round with the King of Hearts!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 7 + 21, or 28, at the end of round 29
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 7 + 17, or 24, at the end of round 29
# *********************************
# Round 30
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[2 of Diamonds]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[5 of Clubs]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 2 of Diamonds / 5 of Clubs <-- Player 2's card
# Player 2 wins the round with the 5 of Clubs!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 6 + 21, or 27, at the end of round 30
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 6 + 19, or 25, at the end of round 30
# *********************************
# Round 31
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[10 of Clubs]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[6 of Spades]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 10 of Clubs / 6 of Spades <-- Player 2's card
# Player 2 wins the round with the 6 of Spades!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 5 + 21, or 26, at the end of round 31
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 5 + 21, or 26, at the end of round 31
# *********************************
# Round 32
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[8 of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[9 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 8 of Spades / 9 of Diamonds <-- Player 2's card
# Player 2 wins the round with the 9 of Diamonds!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 4 + 21, or 25, at the end of round 32
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 4 + 23, or 27, at the end of round 32
# *********************************
# Round 33
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Queen of Clubs]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Jack of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> Queen of Clubs / Jack of Diamonds <-- Player 2's card
# Player 1 wins the round with the Queen of Clubs!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 3 + 23, or 26, at the end of round 33
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 3 + 23, or 26, at the end of round 33
# *********************************
# Round 34
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Jack of Hearts]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Ace of Clubs]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> Jack of Hearts / Ace of Clubs <-- Player 2's card
# Player 1 wins the round with the Jack of Hearts!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 2 + 25, or 27, at the end of round 34
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 2 + 23, or 25, at the end of round 34
# *********************************
# Round 35
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Queen of Hearts]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[5 of Spades]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> Queen of Hearts / 5 of Spades <-- Player 2's card
# Player 1 wins the round with the Queen of Hearts!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 1 + 27, or 28, at the end of round 35
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 1 + 23, or 24, at the end of round 35
# *********************************
# Round 36
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[6 of Diamonds]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[8 of Clubs]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 6 of Diamonds / 8 of Clubs <-- Player 2's card
# Player 2 wins the round with the 8 of Clubs!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 0 + 27, or 27, at the end of round 36
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 0 + 25, or 25, at the end of round 36
# *********************************
# Round 37
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# Player's hand is empty
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# Player's hand is empty
# --Attempting to empty the discard pile for Player 1's Discard Pile--
# Player 1's Discard Pile is not empty: There are 27 cards in it. Emptying into Player 1's Hand
# Shuffling Player 1's Hand
# --Attempting to empty the discard pile for Player 1's Discard Pile--
# Player 2's Discard Pile is not empty: There are 25 cards in it. Emptying into Player 2's Hand
# Shuffling Player 2's Hand
# --Resetting the war stacks from 1's 0 and 2's 0 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 14 + 13, or 27, at the end of round 37
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 13 + 12, or 25, at the end of round 37
# *********************************
# Round 38
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Queen of Hearts]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[King of Hearts]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> Queen of Hearts / King of Hearts <-- Player 2's card
# Player 1 wins the round with the Queen of Hearts!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 13 + 15, or 28, at the end of round 38
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 12 + 12, or 24, at the end of round 38
# *********************************
# Round 39
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[10 of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[6 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 10 of Spades / 6 of Diamonds <-- Player 2's card
# Player 2 wins the round with the 6 of Diamonds!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 12 + 15, or 27, at the end of round 39
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 11 + 14, or 25, at the end of round 39
# *********************************
# Round 40
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Ace of Clubs]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[9 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> Ace of Clubs / 9 of Diamonds <-- Player 2's card
# Player 1 wins the round with the Ace of Clubs!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 11 + 17, or 28, at the end of round 40
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 10 + 14, or 24, at the end of round 40
# *********************************
# Round 41
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[4 of Clubs]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[10 of Clubs]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 4 of Clubs / 10 of Clubs <-- Player 2's card
# Player 1 wins the round with the 4 of Clubs!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 10 + 19, or 29, at the end of round 41
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 9 + 14, or 23, at the end of round 41
# *********************************
# Round 42
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Queen of Clubs]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[7 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> Queen of Clubs / 7 of Diamonds <-- Player 2's card
# Player 1 wins the round with the Queen of Clubs!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 9 + 21, or 30, at the end of round 42
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 8 + 14, or 22, at the end of round 42
# *********************************
# Round 43
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Queen of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Ace of Spades]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> Queen of Spades / Ace of Spades <-- Player 2's card
# Player 1 wins the round with the Queen of Spades!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 8 + 23, or 31, at the end of round 43
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 7 + 14, or 21, at the end of round 43
# *********************************
# Round 44
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Jack of Hearts]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[2 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> Jack of Hearts / 2 of Diamonds <-- Player 2's card
# Player 1 wins the round with the Jack of Hearts!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 7 + 25, or 32, at the end of round 44
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 6 + 14, or 20, at the end of round 44
# *********************************
# Round 45
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[7 of Clubs]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[3 of Clubs]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 7 of Clubs / 3 of Clubs <-- Player 2's card
# Player 1 wins the round with the 7 of Clubs!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 6 + 27, or 33, at the end of round 45
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 5 + 14, or 19, at the end of round 45
# *********************************
# Round 46
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[5 of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[9 of Spades]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 5 of Spades / 9 of Spades <-- Player 2's card
# Player 2 wins the round with the 9 of Spades!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 5 + 27, or 32, at the end of round 46
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 4 + 16, or 20, at the end of round 46
# *********************************
# Round 47
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[King of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[5 of Clubs]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> King of Spades / 5 of Clubs <-- Player 2's card
# Player 1 wins the round with the King of Spades!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# ...
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 1 + 6, or 7, at the end of round 77
# *********************************
# Round 78
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[7 of Clubs]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[8 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 7 of Clubs / 8 of Diamonds <-- Player 2's card
# Player 2 wins the round with the 8 of Diamonds!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 3 + 41, or 44, at the end of round 78
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 0 + 8, or 8, at the end of round 78
# *********************************
# Round 79
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[7 of Diamonds]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# Player's hand is empty
# --Attempting to empty the discard pile for Player 1's Discard Pile--
# Player 2's Discard Pile is not empty: There are 8 cards in it. Emptying into Player 2's Hand
# Shuffling Player 2's Hand
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[8 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 2 + 41, or 43, at the end of round 79
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 3 + 6, or 9, at the end of round 79
# *********************************
# Round 80
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[9 of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Ace of Hearts]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 9 of Spades / Ace of Hearts <-- Player 2's card
# Player 2 wins the round with the Ace of Hearts!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 1 + 41, or 42, at the end of round 80
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 2 + 8, or 10, at the end of round 80
# *********************************
# Round 81
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[6 of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[6 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 6 of Spades / 6 of Diamonds <-- Player 2's card
# Neither player wins! It's a war!
# There was a war!
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 1
# Player's hand is empty
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 1
# --[7 of Clubs]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 2
# --Attempting to empty the discard pile for Player 1's Discard Pile--
# Player 1's Discard Pile is not empty: There are 41 cards in it. Emptying into Player 1's Hand
# Shuffling Player 1's Hand
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 1
# --[Queen of Clubs]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 2
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 2
# --[4 of Diamonds]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 3
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 2
# Player's hand is empty
# --Attempting to empty the discard pile for Player 1's Discard Pile--
# Player 2's Discard Pile is not empty: There are 8 cards in it. Emptying into Player 2's Hand
# Shuffling Player 2's Hand
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 2
# --[9 of Spades]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 3
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 3
# --[10 of Hearts]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 4
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 3
# --[7 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 4
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 4
# --[Jack of Clubs]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 5
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 4
# --[Ace of Hearts]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 5
# --Comparing the player cards. (5 in 1's war stack, 5 in 2's war stack)--
# Player 1's card --> Jack of Clubs / Ace of Hearts <-- Player 2's card
# Player 1 wins the round with the Jack of Clubs!
# Player 1 Wins The War at round 81!
# --Resetting the war stacks from 1's 5 and 2's 5 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 17 + 30, or 47, at the end of round 81
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 1 + 4, or 5, at the end of round 81
# *********************************
# Round 82
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Queen of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[8 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> Queen of Spades / 8 of Diamonds <-- Player 2's card
# Player 1 wins the round with the Queen of Spades!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 16 + 32, or 48, at the end of round 82
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 0 + 4, or 4, at the end of round 82
# *********************************
# Round 83
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[9 of Hearts]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# Player's hand is empty
# --Attempting to empty the discard pile for Player 1's Discard Pile--
# Player 2's Discard Pile is not empty: There are 4 cards in it. Emptying into Player 2's Hand
# Shuffling Player 2's Hand
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[King of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 15 + 34, or 49, at the end of round 83
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 1 + 2, or 3, at the end of round 83
# *********************************
# Round 84
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[10 of Clubs]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[2 of Spades]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 10 of Clubs / 2 of Spades <-- Player 2's card
# Player 2 wins the round with the 2 of Spades!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 14 + 34, or 48, at the end of round 84
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 0 + 4, or 4, at the end of round 84
# *********************************
# Round 85
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[2 of Diamonds]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# Player's hand is empty
# --Attempting to empty the discard pile for Player 1's Discard Pile--
# Player 2's Discard Pile is not empty: There are 4 cards in it. Emptying into Player 2's Hand
# Shuffling Player 2's Hand
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[2 of Spades]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 2 won the round, so all cards go to Player 2's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 13 + 34, or 47, at the end of round 85
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 1 + 4, or 5, at the end of round 85
# *********************************
# Round 86
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[5 of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[10 of Clubs]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 5 of Spades / 10 of Clubs <-- Player 2's card
# Player 1 wins the round with the 5 of Spades!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 12 + 36, or 48, at the end of round 86
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 0 + 4, or 4, at the end of round 86
# *********************************
# Round 87
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[6 of Hearts]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# Player's hand is empty
# --Attempting to empty the discard pile for Player 1's Discard Pile--
# Player 2's Discard Pile is not empty: There are 4 cards in it. Emptying into Player 2's Hand
# Shuffling Player 2's Hand
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[2 of Spades]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 11 + 38, or 49, at the end of round 87
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 1 + 2, or 3, at the end of round 87
# *********************************
# Round 88
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[5 of Diamonds]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[2 of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Comparing the player cards. (1 in 1's war stack, 1 in 2's war stack)--
# Player 1's card --> 5 of Diamonds / 2 of Diamonds <-- Player 2's card
# Player 1 wins the round with the 5 of Diamonds!
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 10 + 40, or 50, at the end of round 88
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 0 + 2, or 2, at the end of round 88
# *********************************
# Round 89
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[8 of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# Player's hand is empty
# --Attempting to empty the discard pile for Player 1's Discard Pile--
# Player 2's Discard Pile is not empty: There are 2 cards in it. Emptying into Player 2's Hand
# Shuffling Player 2's Hand
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Queen of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 9 + 42, or 51, at the end of round 89
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 0 + 1, or 1, at the end of round 89
# *********************************
# Round 90
# --Dealing Cards to Player 1's Hand--
# Before dealing, The Player's war_stack size: 0
# --[10 of Spades]-- Card Dealt Successfully to Player 1's Hand--
# After dealing, the Player's war_stack  size: 1
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# Player's hand is empty
# --Attempting to empty the discard pile for Player 1's Discard Pile--
# Player 2's Discard Pile is not empty: There are 1 cards in it. Emptying into Player 2's Hand
# Shuffling Player 2's Hand
# --Dealing Cards to Player 2's Hand--
# Before dealing, The Player's war_stack size: 0
# --[Ace of Diamonds]-- Card Dealt Successfully to Player 2's Hand--
# After dealing, the Player's war_stack  size: 1
# --Resetting the war stacks from 1's 1 and 2's 1 to Zero (0)--
# Player 1 won the round, so all cards go to Player 1's Discard Pile
# ****Player Totals****
# The total length of Player 1's Hand and Player 1's Discard Pile is:, 8 + 44, or 52, at the end of round 90
# The total length of Player 2's Hand and Player 2's Discard Pile is:, 0 + 0, or 0, at the end of round 90
# Player 2 Wins the game!
